# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
import urllib.parse
import datetime as dt
from urllib.parse import quote_plus as urlquote
from functools import reduce

# %%
covid_vaccine_csv = "../data/covid_vaccine.csv"
covid_cases_csv = "covid_cases.csv"

vaccine_df = pd.read_csv(covid_vaccine_csv)
cases_df = pd.read_csv(covid_cases_csv)

##covid_df = pd.merge(vaccine_df, cases_df)

# %%
cases_df
# Out:
#              date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0      2020-12-08    OK     205999    171497.0     34502.0         0
# 1      2020-08-29    SD      12942         NaN         NaN       425
# 2      2020-11-06    SD      52639         NaN         NaN      1488
# 3      2020-09-21    MP         69        69.0         0.0         0
# 4      2020-06-28    PA      85988     83529.0      2459.0       492
# ...           ...   ...        ...         ...         ...       ...
# 24895  2021-02-10    OH     928631    803885.0    124746.0      3281
# 24896  2020-09-05    TN     162362    158070.0      4292.0      1765
# 24897  2020-10-19    KS      72968     67935.0      5033.0      2113
# 24898  2020-12-05    NY     368246         NaN         NaN      7532
# 24899  2020-03-31    IA        497         NaN         NaN        73
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# ...

# %%
vaccine_df
# Out:
#             date    state  total_vaccinations  total_distributed  \
# 0     2021-01-12  Alabama             78134.0           377025.0
# 1     2021-01-13  Alabama             84040.0           378975.0
# 2     2021-01-14  Alabama             92300.0           435350.0
# 3     2021-01-15  Alabama            100567.0           444650.0
# 4     2021-01-16  Alabama                 NaN                NaN
# ...          ...      ...                 ...                ...
# 3918  2021-03-08  Wyoming            185580.0           236065.0
# 3919  2021-03-09  Wyoming            185813.0           246125.0
# 3920  2021-03-10  Wyoming            190180.0           259495.0
# 3921  2021-03-11  Wyoming            190570.0           262995.0
# 3922  2021-03-12  Wyoming            199232.0           270015.0
#
#       people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0               70861.0                                 0.15
# ...

# %%
cleaned_vaccine = vaccine_df.drop(columns=["total_distributed", "daily_vaccinations_raw"])
cleaned_vaccine
# Out:
#             date    state  total_vaccinations  people_vaccinated  \
# 0     2021-01-12  Alabama             78134.0            70861.0
# 1     2021-01-13  Alabama             84040.0            74792.0
# 2     2021-01-14  Alabama             92300.0            80480.0
# 3     2021-01-15  Alabama            100567.0            86956.0
# 4     2021-01-16  Alabama                 NaN                NaN
# ...          ...      ...                 ...                ...
# 3918  2021-03-08  Wyoming            185580.0           114824.0
# 3919  2021-03-09  Wyoming            185813.0           115046.0
# 3920  2021-03-10  Wyoming            190180.0           116799.0
# 3921  2021-03-11  Wyoming            190570.0           116948.0
# 3922  2021-03-12  Wyoming            199232.0           121792.0
#
#       people_fully_vaccinated_per_hundred  total_vaccinations_per_hundred  \
# 0                                    0.15                            1.59
# ...

# %%
abbv = {
"Alabama": "AL",
"Alaska": "AK",
"Arizona": "AZ",
"Arkansas": "AR",
"California": "CA",
"Colorado": "CO",
"Connecticut": "CT",
"Delaware": "DE",
"Florida": "FL",
"Georgia": "GA",
"Hawaii": "HI",
"Idaho": "ID",
"Illinois": "IL",
"Indiana": "IN",
"Iowa": "IA",
"Kansas": "KS",
"Kentucky":"KY",
"Louisiana": "LA",
"Maine" : "ME",
"Maryland": "MD",
"Massachusetts":"MA",
"Michigan" : "MI",
"Minnesota":"MN",
"Mississippi":"MS",
"Missouri":"MO",
"Montana":"MT",
"Nebraska":"NE",
"Nevada":"NV",
"New Hampshire":"NH",
"New Jersey":"NJ",
"New Mexico":"NM",
"New York State":"NY",
"North Carolina":"NC",
"North Dakota":"ND",
"Ohio":"OH",
"Oklahoma":"OK",
"Oregon": "OR",
"Pennsylvania":"PA",
"Rhode Island":"RI",
"South Carolina":"SC",
"South Dakota":"SD",
"Tennessee":"TN",
"Texas":"TX",
"Utah":"UT",
"Vermont":"VT",
"Virginia":"VA",
"Washington":"WA",
"West Virginia": "WV",
"Wisconsin":"WI",
"Wyoming":"WY",
"American Samoa": "AS",
"Guam": "GU",
"Puerto Rico": "PR",
"Marshall Islands":"MH",
"Virgin Islands": "VI"
}
cleaned_vaccine['state'] = vaccine_df.state.replace(abbv)
cleaned_vaccine
# Out:
#             date state  total_vaccinations  people_vaccinated  \
# 0     2021-01-12    AL             78134.0            70861.0
# 1     2021-01-13    AL             84040.0            74792.0
# 2     2021-01-14    AL             92300.0            80480.0
# 3     2021-01-15    AL            100567.0            86956.0
# 4     2021-01-16    AL                 NaN                NaN
# ...          ...   ...                 ...                ...
# 3918  2021-03-08    WY            185580.0           114824.0
# 3919  2021-03-09    WY            185813.0           115046.0
# 3920  2021-03-10    WY            190180.0           116799.0
# 3921  2021-03-11    WY            190570.0           116948.0
# 3922  2021-03-12    WY            199232.0           121792.0
#
#       people_fully_vaccinated_per_hundred  total_vaccinations_per_hundred  \
# 0                                    0.15                            1.59
# ...

# %%
cases_df
# Out:
#              date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0      2020-12-08    OK     205999    171497.0     34502.0         0
# 1      2020-08-29    SD      12942         NaN         NaN       425
# 2      2020-11-06    SD      52639         NaN         NaN      1488
# 3      2020-09-21    MP         69        69.0         0.0         0
# 4      2020-06-28    PA      85988     83529.0      2459.0       492
# ...           ...   ...        ...         ...         ...       ...
# 24895  2021-02-10    OH     928631    803885.0    124746.0      3281
# 24896  2020-09-05    TN     162362    158070.0      4292.0      1765
# 24897  2020-10-19    KS      72968     67935.0      5033.0      2113
# 24898  2020-12-05    NY     368246         NaN         NaN      7532
# 24899  2020-03-31    IA        497         NaN         NaN        73
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# ...

# %%
start_date = "2021-01-12"
end_date = "2021-3-12"

ncases = (cases_df['date'] > start_date) & (cases_df['date'] <= end_date)

cases_df = cases_df.loc[ncases]
cases_df
# Out:
#              date state  tot_cases  conf_cases  prob_cases  new_case  \
# 10     2021-01-27   NYC     592471    508530.0     83941.0      6182
# 22     2021-02-07   RMI          4         4.0         0.0         0
# 25     2021-03-01    AR     322509         NaN         NaN        94
# 45     2021-01-13    MP        128       128.0         0.0         0
# 51     2021-01-16    OH     821507    725111.0     96396.0      7065
# ...           ...   ...        ...         ...         ...       ...
# 24872  2021-02-21    KS     290832    236146.0     54686.0         0
# 24873  2021-02-08    PW          0         NaN         NaN         0
# 24882  2021-03-09    MP        146       146.0         0.0         0
# 24894  2021-01-24    UT     336405    336405.0         0.0      1516
# 24895  2021-02-10    OH     928631    803885.0    124746.0      3281
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# ...

# %%
cleaned_cases = cases_df.drop(columns=["conf_cases", "prob_cases", "pnew_case", "prob_death", "pnew_death", "created_at", "consent_cases", "consent_deaths"])
cleaned_cases
# Out:
#              date state  tot_cases  new_case  tot_death  conf_death  new_death
# 10     2021-01-27   NYC     592471      6182      26858     21887.0         93
# 22     2021-02-07   RMI          4         0          0         0.0          0
# 25     2021-03-01    AR     322509        94       5250         NaN          7
# 45     2021-01-13    MP        128         0          2         2.0          0
# 51     2021-01-16    OH     821507      7065      10135      9080.0         78
# ...           ...   ...        ...       ...        ...         ...        ...
# 24872  2021-02-21    KS     290832         0       4614         NaN          0
# 24873  2021-02-08    PW          0         0          0         NaN          0
# 24882  2021-03-09    MP        146         0          2         2.0          0
# 24894  2021-01-24    UT     336405      1516       1595      1550.0         13
# 24895  2021-02-10    OH     928631      3281      11856     10522.0         63
#
# [3480 rows x 7 columns]

# %%
#cleaned_cases_cols = ["date","state","death","deathIncrease","hospitalized","hospitalizedIncrease","positive","positiveIncrease","totalTestResults"]
#cleaned_cases_transformed= cleaned_cases[cleaned_cases_cols].copy()
#cleaned_cases_transformed = cleaned_cases_transformed.rename(columns={
 #                                                    "date": "date",
  #                                                   "state": "state",
        #                                             "death": "death",
         #                                            "deathIncrease": "death_Increase",
          #                                           "hospitalized": "hospitalized",
           #                                          "hospitalizedIncrease": "hospitalized_Increase",
                                                    #"positive": "positive",
                                                     #"positiveIncrease": "positive_Increase",})
                    
                    
#cleaned_cases_transformed

# %%
#cleaned_cases['date'] = pd.to_datetime(cleaned_cases['date'])

# %%
cleaned_cases
cleaned_vaccine

cleaned_cases['date'] = pd.to_datetime(cleaned_cases['date'])
cleaned_vaccine['date'] = pd.to_datetime(cleaned_vaccine['date'])
merged_df = pd.merge(cleaned_cases, cleaned_vaccine, on= ["date" , "state"])

# %%
connection_string = "postgres:Cellxan69$$@localhost:5432/covid_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['covid']

# %%
merged_df.to_sql(name= 'covid', con=engine, if_exists= 'replace', index= False)

# %%
df = pd.read_sql_query('SELECT * FROM covid', engine)

# %%
df
# Out:
#            date state  tot_cases  new_case  tot_death  conf_death  new_death  \
# 0    2021-03-01    AR     322509        94       5250         NaN          7
# 1    2021-01-16    OH     821507      7065      10135      9080.0         78
# 2    2021-02-14    AR     313028       466       5265         NaN         13
# 3    2021-02-26    KS     293663       826       4735         NaN         11
# 4    2021-01-19    SD     105786       127       1667      1346.0          0
# ...         ...   ...        ...       ...        ...         ...        ...
# 3127 2021-01-23    NM     168579       848       3115         NaN         38
# 3128 2021-03-04    SD     113065       232       1896      1538.0          3
# 3129 2021-02-21    KS     290832         0       4614         NaN          0
# 3130 2021-01-24    UT     336405      1516       1595      1550.0         13
# 3131 2021-02-10    OH     928631      3281      11856     10522.0         63
#
# ...

# %%
covid_dict = df.to_dict(orient='records')

# %%
import pymongo

# Setup connection to mongodb
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# Select database and collection to use
db = client.covid_db
covid = db.covid

# %%
covid.insert_many(covid_dict)

# %%
us_csv = "us_covid_vacination_data.csv"
us_cases_csv = "us_cases.csv"
us_deaths_csv = "us_deaths.csv"

us_vaccines = pd.read_csv(us_csv)
us_cases = pd.read_csv(us_cases_csv)
us_deaths = pd.read_csv(us_deaths_csv)

# %%
us_vaccines
# Out:
#          location      date                                    vaccine  \
# 0   United States  12/20/20                            Pfizer/BioNTech
# 1   United States  12/21/20                            Pfizer/BioNTech
# 2   United States  12/23/20                   Moderna, Pfizer/BioNTech
# 3   United States  12/26/20                   Moderna, Pfizer/BioNTech
# 4   United States  12/28/20                   Moderna, Pfizer/BioNTech
# ..            ...       ...                                        ...
# 63  United States    3/7/21  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 64  United States    3/8/21  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 65  United States    3/9/21  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 66  United States   3/10/21  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 67  United States   3/11/21  Johnson&Johnson, Moderna, Pfizer/BioNTech
#
#                                            source_url  total_vaccinations  \
# ...

# %%
us_cases
# Out:
#             date  New Cases  7-Day Moving Avg
# 0    Mar 11 2021      60678             66307
# 1    Mar 10 2021      60375             67178
# 2     Mar 9 2021      52815             68092
# 3     Mar 8 2021     124266             68312
# 4     Mar 7 2021      41606             57813
# ..           ...        ...               ...
# 410  Jan 26 2020          3                 0
# 411  Jan 25 2020          0                 0
# 412  Jan 24 2020          1                 0
# 413  Jan 23 2020          0                 0
# 414  Jan 22 2020          1                 0
#
# [415 rows x 3 columns]

# %%
us_deaths
# Out:
#             date  New Deaths  7-Day Moving Avg
# 0    Mar 11 2021        1572              1447
# 1    Mar 10 2021        1516              1484
# 2     Mar 9 2021        1503              1547
# 3     Mar 8 2021         844              1635
# 4     Mar 7 2021         848              1697
# ..           ...         ...               ...
# 410  Jan 26 2020           0                 0
# 411  Jan 25 2020           0                 0
# 412  Jan 24 2020           0                 0
# 413  Jan 23 2020           0                 0
# 414  Jan 22 2020           0                 0
#
# [415 rows x 3 columns]

# %%
us_vaccines['date'] = pd.to_datetime(us_vaccines['date'])
us_cases['date'] = pd.to_datetime(us_cases['date'])
us_deaths['date'] = pd.to_datetime(us_deaths['date'])

# %%
us1_df = pd.merge(us_vaccines, us_cases, on= ["date" ])

# %%
us_df = pd.merge(us1_df, us_deaths, on= ["date"])

# %%
us_df
# Out:
#          location       date                                    vaccine  \
# 0   United States 2020-12-20                            Pfizer/BioNTech
# 1   United States 2020-12-21                            Pfizer/BioNTech
# 2   United States 2020-12-23                   Moderna, Pfizer/BioNTech
# 3   United States 2020-12-26                   Moderna, Pfizer/BioNTech
# 4   United States 2020-12-28                   Moderna, Pfizer/BioNTech
# ..            ...        ...                                        ...
# 63  United States 2021-03-07  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 64  United States 2021-03-08  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 65  United States 2021-03-09  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 66  United States 2021-03-10  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 67  United States 2021-03-11  Johnson&Johnson, Moderna, Pfizer/BioNTech
#
#                                            source_url  total_vaccinations  \
# ...

# %%
us_df.loc['2021-01-12':'2021-03-11']
# Out:
# Empty DataFrame
# Columns: [date, vaccine, total_vaccinations, people_vaccinated, people_fully_vaccinated, New Cases, 7-Day Moving Avg_x, New Deaths, 7-Day Moving Avg_y]
# Index: []

# %%
us_df= us_df.drop(columns=["location", "source_url"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-fe94e7075f58> in <module>
# ----> 1 us_df= us_df.drop(columns=["location", "source_url"])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
us_df

# %%
us_df.to_sql(name= 'covid', con=engine, if_exists= 'replace', index= False)

# %%
us_dict = us_df.to_dict(orient='records')

# %%
import pymongo

# Setup connection to mongodb
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# Select database and collection to use
db = client.covid_db
us = db.us

# %%
covid.insert_many(us_dict)

# %%
us_df.to_csv('/Users/marcellisv/Desktop/GitHub/Final_Projec/data/combined_us_data.csv', index=False)

# %%
us_df.to_html('/Users/marcellisv/Desktop/GitHub/Final_Projec/data/combined_us_data.html', index=False)
