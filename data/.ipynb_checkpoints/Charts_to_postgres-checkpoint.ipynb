# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
import urllib.parse
import datetime as dt
from urllib.parse import quote_plus as urlquote

# %%
covid_vaccine_csv = "../data/covid_vaccine.csv"
covid_cases_csv = "../data/covid_cases.csv"

vaccine_df = pd.read_csv(covid_vaccine_csv)
cases_df = pd.read_csv(covid_cases_csv)

##covid_df = pd.merge(vaccine_df, cases_df)

# %%
vaccine_df
# Out:
#             date location  total_vaccinations  total_distributed  \
# 0     2021-01-12  Alabama             78134.0           377025.0
# 1     2021-01-13  Alabama             84040.0           378975.0
# 2     2021-01-14  Alabama             92300.0           435350.0
# 3     2021-01-15  Alabama            100567.0           444650.0
# 4     2021-01-16  Alabama                 NaN                NaN
# ...          ...      ...                 ...                ...
# 3333  2021-02-27  Wyoming            151584.0           195855.0
# 3334  2021-02-28  Wyoming            156397.0           195855.0
# 3335  2021-03-01  Wyoming            156741.0           195855.0
# 3336  2021-03-02  Wyoming            156776.0           211415.0
# 3337  2021-03-03  Wyoming            162918.0           217215.0
#
#       people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0               70861.0                                 0.15
# 1               74792.0                                 0.19
# 2               80480.0                                  NaN
# 3               86956.0                                 0.27
# 4                   NaN                                  NaN
# ...                 ...                                  ...
# 3333            98484.0                                 9.09
# 3334           100902.0                                 9.50
# 3335           100903.0                                 9.56
# 3336           100911.0                                 9.56
# 3337           104459.0                                10.00
#
#       total_vaccinations_per_hundred  people_fully_vaccinated  \
# 0                               1.59                   7270.0
# 1                               1.71                   9245.0
# 2                               1.88                      NaN
# 3                               2.05                  13488.0
# 4                                NaN                      NaN
# ...                              ...                      ...
# 3333                           26.19                  52608.0
# 3334                           27.02                  54962.0
# 3335                           27.08                  55305.0
# 3336                           27.09                  55332.0
# 3337                           28.15                  57895.0
#
#       people_vaccinated_per_hundred  distributed_per_hundred  \
# 0                              1.44                     7.69
# 1                              1.52                     7.73
# 2                              1.64                     8.88
# 3                              1.77                     9.07
# 4                               NaN                      NaN
# ...                             ...                      ...
# 3333                          17.02                    33.84
# 3334                          17.43                    33.84
# 3335                          17.43                    33.84
# 3336                          17.44                    36.53
# 3337                          18.05                    37.53
#
#       daily_vaccinations_raw  daily_vaccinations  \
# 0                        NaN                 NaN
# 1                     5906.0              5906.0
# 2                     8260.0              7083.0
# 3                     8267.0              7478.0
# 4                     7557.0              7498.0
# ...                      ...                 ...
# 3333                  6007.0              3218.0
# 3334                  4813.0              3847.0
# 3335                   344.0              3015.0
# 3336                    35.0              2945.0
# 3337                  6142.0              3793.0
#
#       daily_vaccinations_per_million  share_doses_used
# 0                                NaN             0.207
# 1                             1205.0             0.222
# 2                             1445.0             0.212
# 3                             1525.0             0.226
# 4                             1529.0               NaN
# ...                              ...               ...
# 3333                          5560.0             0.774
# 3334                          6647.0             0.799
# 3335                          5209.0             0.800
# 3336                          5088.0             0.742
# 3337                          6554.0             0.750
#
# [3338 rows x 14 columns]

# %%
vaccine_df.drop(columns=["total_distributed", "daily_vaccinations_raw", "share_doses_used"])
# Out:
#             date location  total_vaccinations  people_vaccinated  \
# 0     2021-01-12  Alabama             78134.0            70861.0
# 1     2021-01-13  Alabama             84040.0            74792.0
# 2     2021-01-14  Alabama             92300.0            80480.0
# 3     2021-01-15  Alabama            100567.0            86956.0
# 4     2021-01-16  Alabama                 NaN                NaN
# ...          ...      ...                 ...                ...
# 3333  2021-02-27  Wyoming            151584.0            98484.0
# 3334  2021-02-28  Wyoming            156397.0           100902.0
# 3335  2021-03-01  Wyoming            156741.0           100903.0
# 3336  2021-03-02  Wyoming            156776.0           100911.0
# 3337  2021-03-03  Wyoming            162918.0           104459.0
#
#       people_fully_vaccinated_per_hundred  total_vaccinations_per_hundred  \
# 0                                    0.15                            1.59
# 1                                    0.19                            1.71
# 2                                     NaN                            1.88
# 3                                    0.27                            2.05
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 3333                                 9.09                           26.19
# 3334                                 9.50                           27.02
# 3335                                 9.56                           27.08
# 3336                                 9.56                           27.09
# 3337                                10.00                           28.15
#
#       people_fully_vaccinated  people_vaccinated_per_hundred  \
# 0                      7270.0                           1.44
# 1                      9245.0                           1.52
# 2                         NaN                           1.64
# 3                     13488.0                           1.77
# 4                         NaN                            NaN
# ...                       ...                            ...
# 3333                  52608.0                          17.02
# 3334                  54962.0                          17.43
# 3335                  55305.0                          17.43
# 3336                  55332.0                          17.44
# 3337                  57895.0                          18.05
#
#       distributed_per_hundred  daily_vaccinations  \
# 0                        7.69                 NaN
# 1                        7.73              5906.0
# 2                        8.88              7083.0
# 3                        9.07              7478.0
# 4                         NaN              7498.0
# ...                       ...                 ...
# 3333                    33.84              3218.0
# 3334                    33.84              3847.0
# 3335                    33.84              3015.0
# 3336                    36.53              2945.0
# 3337                    37.53              3793.0
#
#       daily_vaccinations_per_million
# 0                                NaN
# 1                             1205.0
# 2                             1445.0
# 3                             1525.0
# 4                             1529.0
# ...                              ...
# 3333                          5560.0
# 3334                          6647.0
# 3335                          5209.0
# 3336                          5088.0
# 3337                          6554.0
#
# [3338 rows x 11 columns]

# %%
cases_df
# Out:
#       submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0          05/04/2020    KY       5245      5245.0         0.0       115
# 1          03/23/2020    NH        101         NaN         NaN        23
# 2          10/28/2020    RI      31944         NaN         NaN       499
# 3          05/29/2020    NJ     159196         NaN         NaN      1673
# 4          02/14/2020    DC          0         NaN         NaN         0
# ...               ...   ...        ...         ...         ...       ...
# 24535      03/23/2020    RI        106         NaN         NaN         9
# 24536      10/09/2020    GU       2989         NaN         NaN         0
# 24537      07/12/2020    DC      10847         NaN         NaN        46
# 24538      03/05/2020    MI          0         NaN         NaN         0
# 24539      02/03/2021    CA    3281271         NaN         NaN     10501
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# 0            0.0        261       261.0         0.0          8         0.0
# 1            NaN          1         NaN         NaN          1         NaN
# 2            0.0       1192         NaN         NaN          4         0.0
# 3           14.0      11531     11531.0         0.0        130         0.0
# 4            NaN          0         NaN         NaN          0         NaN
# ...          ...        ...         ...         ...        ...         ...
# 24535        NaN          0         NaN         NaN          0         NaN
# 24536        0.0         58         NaN         NaN          0         0.0
# 24537        0.0        568         NaN         NaN          0         0.0
# 24538        NaN          0         NaN         NaN          0         NaN
# 24539        0.0      41811         NaN         NaN        481         0.0
#
#                    created_at consent_cases consent_deaths
# 0      05/05/2020 05:25:08 PM         Agree          Agree
# 1      03/26/2020 04:22:39 PM     Not agree      Not agree
# 2      10/29/2020 02:11:33 PM     Not agree            NaN
# 3      02/19/2021 01:38:31 PM     Not agree          Agree
# 4      03/26/2020 04:22:39 PM           NaN            NaN
# ...                       ...           ...            ...
# 24535  03/26/2020 04:22:39 PM     Not agree            NaN
# 24536  10/10/2020 01:30:17 PM     Not agree      Not agree
# 24537  07/13/2020 03:19:34 PM           NaN            NaN
# 24538  03/26/2020 04:22:39 PM         Agree          Agree
# 24539  02/04/2021 02:53:58 PM     Not agree      Not agree
#
# [24540 rows x 15 columns]

# %%
cases_df.drop(columns=["prob_cases", "pnew_case", "prob_death", "pnew_death", "created_at", "consent_cases", "consent_deaths"])
# Out:
#       submission_date state  tot_cases  conf_cases  new_case  tot_death  \
# 0          05/04/2020    KY       5245      5245.0       115        261
# 1          03/23/2020    NH        101         NaN        23          1
# 2          10/28/2020    RI      31944         NaN       499       1192
# 3          05/29/2020    NJ     159196         NaN      1673      11531
# 4          02/14/2020    DC          0         NaN         0          0
# ...               ...   ...        ...         ...       ...        ...
# 24535      03/23/2020    RI        106         NaN         9          0
# 24536      10/09/2020    GU       2989         NaN         0         58
# 24537      07/12/2020    DC      10847         NaN        46        568
# 24538      03/05/2020    MI          0         NaN         0          0
# 24539      02/03/2021    CA    3281271         NaN     10501      41811
#
#        conf_death  new_death
# 0           261.0          8
# 1             NaN          1
# 2             NaN          4
# 3         11531.0        130
# 4             NaN          0
# ...           ...        ...
# 24535         NaN          0
# 24536         NaN          0
# 24537         NaN          0
# 24538         NaN          0
# 24539         NaN        481
#
# [24540 rows x 8 columns]

# %%
#vaccination_start_date = dt.date(2021,1,12) + dt.timedelta(days=52)
#print(vaccination_start_date)

# %%
##vaccine_cols = "date", "location", "total_vaccinations",  "people_vaccinated", "people_fully_vaccinated_per_hundred", total_vaccinations_per_hundred	people_fully_vaccinated	people_vaccinated_per_hundred, "distributed_per_hundred", 
             ##  "daily_vaccinations", "daily_vaccinations_per_million"
##vaccine_col_tranfromed = vaccine_transformed.rename()

# %%
connection_string = "postgres:Cellxan69$$@localhost:5432/covid_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['vaccine', 'cases']

# %%
vaccine_df.to_sql(name= "vaccine", con=engine, if_exists= 'append', index= True)

# %%
cases_df.to_sql(name= "cases", con=engine, if_exists= 'append', index= True)
